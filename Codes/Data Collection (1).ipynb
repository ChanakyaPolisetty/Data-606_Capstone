# %%
import sqlalchemy
import pymysql

# %%
pymysql.install_as_MySQLdb()

# %%
index = ['Nasdaq']

# %%
def schemacreator(x):
    engine = sqlalchemy.create_engine('mysql://root:12345678@localhost:3306/')
    engine.execute(sqlalchemy.schema.CreateSchema(x))

# %%
for i in index:
    schemacreator(i)

# %%
import pandas as pd

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Nasdaq-100')[1]
df
# Out:
#    Category  All-Time Highs[8]        All-Time Highs[8].1
# 0   Closing           16573.34  Friday, November 19, 2021
# 1  Intraday           16764.86  Monday, November 22, 2021

# %%
sc_df = pd.read_html('https://en.wikipedia.org/wiki/Nasdaq-100')[4]
sc_df
# Out:
#                        Company Ticker             GICS Sector  \
# 0          Activision Blizzard   ATVI  Communication Services
# 1                   Adobe Inc.   ADBE  Information Technology
# 2                          ADP    ADP  Information Technology
# 3                       Airbnb   ABNB  Consumer Discretionary
# 4             Align Technology   ALGN             Health Care
# ..                         ...    ...                     ...
# 96      Warner Bros. Discovery    WBD  Communication Services
# 97               Workday, Inc.   WDAY  Information Technology
# 98                 Xcel Energy    XEL               Utilities
# 99   Zoom Video Communications     ZM  Information Technology
# 100                    Zscaler     ZS  Information Technology
#
#                          GICS Sub-Industry
# 0           Interactive Home Entertainment
# 1                     Application Software
# 2    Data Processing & Outsourced Services
# 3       Internet & Direct Marketing Retail
# ...

# %%
sc_df['GICS Sector'].value_counts()
# Out:
# Information Technology    39
# Consumer Discretionary    16
# Health Care               13
# Communication Services    11
# Industrials                9
# Consumer Staples           7
# Utilities                  4
# Energy                     2
# Name: GICS Sector, dtype: int64

# %%
sc_df['GICS Sub-Industry'].value_counts()
# Out:
# Application Software                          14
# Semiconductors                                11
# Internet & Direct Marketing Retail             7
# Biotechnology                                  7
# Data Processing & Outsourced Services          4
# Semiconductor Equipment                        4
# Health Care Equipment                          3
# Multi-Utilities                                3
# Interactive Media & Services                   3
# Automobile Manufacturers                       3
# Soft Drinks                                    3
# Broadcasting                                   2
# Packaged Foods & Meats                         2
# Systems Software                               2
# Research & Consulting Services                 2
# Interactive Home Entertainment                 2
# Diversified Support Services                   2
# Cable & Satellite                              2
# IT Consulting & Other Services                 1
# ...

# %%
sc_df[sc_df['GICS Sub-Industry']=='Semiconductors']
# Out:
#                         Company Ticker             GICS Sector  \
# 8   Advanced Micro Devices Inc.    AMD  Information Technology
# 11               Analog Devices    ADI  Information Technology
# 22                Broadcom Inc.   AVGO  Information Technology
# 47              GlobalFoundries    GFS  Information Technology
# 51                        Intel   INTC  Information Technology
# 65         Microchip Technology   MCHP  Information Technology
# 66            Micron Technology     MU  Information Technology
# 72                       Nvidia   NVDA  Information Technology
# 73                          NXP   NXPI  Information Technology
# 82                     Qualcomm   QCOM  Information Technology
# 92            Texas Instruments    TXN  Information Technology
#
#    GICS Sub-Industry
# 8     Semiconductors
# 11    Semiconductors
# 22    Semiconductors
# 47    Semiconductors
# 51    Semiconductors
# 65    Semiconductors
# 66    Semiconductors
# 72    Semiconductors
# ...

# %%
sc_df = sc_df[sc_df['GICS Sub-Industry']=='Semiconductors'].Ticker.to_list()

# %%
import yfinance
import warnings
warnings.filterwarnings("ignore")

# %%
engine = sqlalchemy.create_engine('mysql://root:12345678@localhost:3306/nasdaq')
for i in sc_df:
    df = yfinance.download(i,start='2017-01-01',end='2023-01-01')
    df = df.reset_index()
    df.to_sql(i,engine)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2017-01-03  73.529999  74.309998  73.050003  73.580002  61.881756  4847900
# 1 2017-01-04  73.650002  73.970001  73.250000  73.489998  61.806049  4507100
# 2 2017-01-05  73.290001  73.699997  72.889999  72.919998  61.326672  4301100
# 3 2017-01-06  72.879997  74.279999  72.470001  74.150002  62.361137  5244600
# 4 2017-01-09  74.510002  75.220001  74.169998  74.339996  62.520931  4782900
